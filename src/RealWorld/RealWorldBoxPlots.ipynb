# %%
import matplotlib.pyplot as plt
import pandas as pd
import os

# %%
folder_path = "../../data/output/RealWorld/facebookArtist/"
files=os.listdir(folder_path)
data0=[]
data10=[]
data20=[]
data30=[]
data40=[]
data50=[]
data60=[]
data70=[]
data80=[]
data90=[]
data100=[]

for file in files:
    with open(os.path.join(folder_path, file), 'r') as f:
        content = pd.read_csv(folder_path+"/"+file, names=['Epoch', 'Pop', 'Frac', 'DiscEdge'], skiprows=1, sep=" ")
        file=file.split('_')
        
        content=content.drop(['Epoch', 'Pop'], axis=1)    
        last_row_content=content.iloc[-1, 0]
        if last_row_content>0.5:
            last_row_content=1-last_row_content
        if file[1]=='r0':
            data0.append(float(last_row_content))
        elif file[1]=='r10':
            data10.append(float(last_row_content))
        elif file[1]=='r20':
            data20.append(float(last_row_content))
        elif file[1]=='r30':
            data30.append(float(last_row_content))
        elif file[1]=='r40':
            data40.append(float(last_row_content))
        elif file[1]=='r50':
            data50.append(float(last_row_content))
        elif file[1]=='r60':
            data60.append(float(last_row_content))
        elif file[1]=='r70':
            data70.append(float(last_row_content))
        elif file[1]=='r80':
            data80.append(float(last_row_content))
        elif file[1]=='r90':
            data90.append(float(last_row_content))
        elif file[1]=='r100':
            data100.append(float(last_row_content))

my_dict={'0.0':data0, '0.1':data10, '0.2':data20, '0.3':data30, '0.4':data40, '0.5':data50, '0.6':data60, '0.7':data70, '0.8':data80, '0.9':data90, '1.0':data100}
print(my_dict)
# Out:
# {'0.0': [0.032445999999999975, 0.0329803, 0.03157500000000002, 0.0317925, 0.031694, 0.03189200000000003, 0.030406999999999962, 0.031555, 0.03137699999999999, 0.030922000000000005, 0.03159500000000004, 0.030545000000000044, 0.03203, 0.031178999999999957, 0.0318123, 0.03171299999999999, 0.030308, 0.03173300000000001, 0.030881999999999965, 0.03145600000000004, 0.031039999999999957, 0.03321799999999997, 0.032208000000000014, 0.030922000000000005], '0.1': [0.038583000000000034, 0.038424000000000014, 0.03983000000000003, 0.03693999999999997, 0.03646400000000005, 0.03931499999999999, 0.038860000000000006, 0.03978999999999999, 0.03828600000000004, 0.040127000000000024, 0.040502999999999956, 0.03804799999999997, 0.03941399999999995, 0.03947299999999998, 0.03848399999999996, 0.038246, 0.03786999999999996, 0.03786999999999996, 0.03891900000000004, 0.03923600000000005, 0.040305000000000035, 0.038403999999999994, 0.03775099999999998], '0.2': [0.04634300000000002, 0.04685700000000004, 0.04572900000000002, 0.04772799999999999, 0.04705499999999996, 0.04529300000000003, 0.04776800000000003, 0.0478472, 0.22747700000000004, 0.04713500000000004, 0.04487799999999997, 0.04610499999999995, 0.048321999999999976, 0.04614499999999999, 0.060634999999999994, 0.0480451, 0.045848, 0.046838000000000046, 0.04899500000000001, 0.046679000000000026, 0.047926000000000024, 0.06116999999999995, 0.04735199999999995, 0.046560000000000046], '0.3': [0.05822000000000005, 0.057686000000000015, 0.07