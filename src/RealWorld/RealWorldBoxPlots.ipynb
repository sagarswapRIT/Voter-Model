# %%
import matplotlib.pyplot as plt
import pandas as pd
import os

# %%
folder_path = "../../data/output/RealWorld/facebookMedium/"
files=os.listdir(folder_path)
data0=[]
data10=[]
data20=[]
data30=[]
data40=[]
data50=[]
data60=[]
data70=[]
data80=[]
data90=[]
data100=[]

for file in files:
    with open(os.path.join(folder_path, file), 'r') as f:
        content = pd.read_csv(folder_path+"/"+file, names=['Epoch', 'Pop', 'Frac', 'DiscEdge'], skiprows=1, sep=" ")
        file=file.split('_')
        
        content=content.drop(['Epoch', 'Pop'], axis=1)    
        last_row_content=content.iloc[-1, 0]
        if last_row_content>0.5:
            last_row_content=1-last_row_content
        if file[1]=='r0':
            data0.append(float(last_row_content))
        elif file[1]=='r10':
            data10.append(float(last_row_content))
        elif file[1]=='r20':
            data20.append(float(last_row_content))
        elif file[1]=='r30':
            data30.append(float(last_row_content))
        elif file[1]=='r40':
            data40.append(float(last_row_content))
        elif file[1]=='r50':
            data50.append(float(last_row_content))
        elif file[1]=='r60':
            data60.append(float(last_row_content))
        elif file[1]=='r70':
            data70.append(float(last_row_content))
        elif file[1]=='r80':
            data80.append(float(last_row_content))
        elif file[1]=='r90':
            data90.append(float(last_row_content))
        elif file[1]=='r100':
            data100.append(float(last_row_content))

my_dict={'0.0':data0, '0.1':data10, '0.2':data20, '0.3':data30, '0.4':data40, '0.5':data50, '0.6':data60, '0.7':data70, '0.8':data80, '0.9':data90, '1.0':data100}
print(my_dict)
# Out:
# {'0.0': [0.116066, 0.08037399999999995, 0.343035, 0.184602, 0.12794799999999995, 0.10587400000000002, 0.11726700000000001, 0.0930129, 0.171429, 0.11673299999999998, 0.08798399999999995, 0.10396099999999997, 0.15616399999999997, 0.169114, 0.11277300000000001, 0.09350199999999997, 0.14770799999999995, 0.319404, 0.117178, 0.315665, 0.11909199999999998, 0.10765499999999995, 0.101958, 0.16270600000000002, 0.24227900000000002, 0.07004900000000003, 0.12972899999999998], '0.1': [0.33498000000000006, 0.448331, 0.19345800000000002, 0.20284800000000003, 0.304628, 0.276502, 0.36016899999999996, 0.16061400000000003, 0.269025, 0.28656000000000004, 0.232799, 0.338496, 0.214241, 0.30618599999999996, 0.18874100000000005, 0.406498, 0.174544, 0.21384099999999995, 0.29586100000000004, 0.410859, 0.35491799999999996, 0.229016, 0.235158, 0.341344, 0.339297, 0.30863399999999996, 0.24552700000000005, 0.192434, 0.25558499999999995, 0.494437, 0.318558, 0.259724, 0.367601, 0.350556, 0.21317299999999995, 0.262216], '0.2': [0.414775, 0.22501099999999996, 0.18598099999999995, 0.18856300000000004, 0.245572, 0.335692, 0.35051200000000005, 0.28900800000000004, 0.24450400000000005, 0.351402, 0.26729, 0.31255, 0.22923899999999997, 0.3336, 0.22656900000000002, 0.24000900000000003, 0.29501599999999994, 0.220383, 0.17303100000000005, 0.24365800000000004, 0.26604399999999995, 0.22558999999999996, 0.263106, 0.18126399999999998, 0.31682200000000005, 0.363818, 0.23182000000000003, 0.25385, 0.340053, 0.306809, 0.24307999999999996, 0.21